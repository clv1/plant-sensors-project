# %%
import pandas as pd
import altair as alt

# %%
plants_data = pd.concat(
    map(pd.read_csv, ['example_dataset_1.csv', 'example_dataset_2.csv', 'example_dataset_3.csv']), ignore_index=True)

# %%
plants_data
# Out:
#      plant_id                       name            scientific_name  \
# 0           0          Epipremnum Aureum          Epipremnum aureum
# 1           1              Venus flytrap                        NaN
# 2           2              Corpse flower                        NaN
# 3           3         Rafflesia arnoldii                        NaN
# 4           4           Black bat flower                        NaN
# ..        ...                        ...                        ...
# 131        45                    Begonia        Begonia 'Art Hodes'
# 132        46        Medinilla Magnifica        Medinilla magnifica
# 133        47  Calliandra Haematocephala  Calliandra haematocephala
# 134        48     Zamioculcas Zamiifolia     Zamioculcas zamiifolia
# 135        49             Crassula Ovata             Crassula ovata
#
#             last_watered      recording_taken  soil_moisture  temperature  \
# 0    2023-12-20 14:03:04  2023-12-20 16:31:32      91.375861    13.186697
# 1    2023-12-20 13:54:32  2023-12-20 16:31:39      90.721345    12.040796
# 2    2023-12-20 14:10:54  2023-12-20 16:31:44      92.310616     9.154856
# 3    2023-12-20 14:50:16  2023-12-20 16:31:50      94.145781    10.017372
# 4    2023-12-20 13:16:25  2023-12-20 16:32:00      88.334925    11.339948
# ..                   ...                  ...            ...          ...
# 131  2023-12-20 14:04:23  2023-12-20 16:27:24      91.700767     9.017290
# 132  2023-12-20 14:12:39  2023-12-20 16:27:33      92.546778    13.329321
# 133  2023-12-20 13:30:18  2023-12-20 16:27:41      84.794814    13.348551
# 134  2023-12-20 14:31:09  2023-12-20 16:27:51      93.161707    14.898908
# 135  2023-12-20 14:02:15  2023-12-20 16:27:59      91.502147     9.403629
#
#                           email botanist_first_name botanist_last_name  \
# 0      carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
# 1    gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 2      carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
# 3      eliza.andrews@lnhm.co.uk               Eliza            Andrews
# 4      carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
# ..                          ...                 ...                ...
# 131  gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 132    eliza.andrews@lnhm.co.uk               Eliza            Andrews
# 133    eliza.andrews@lnhm.co.uk               Eliza            Andrews
# 134    carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
# 135    eliza.andrews@lnhm.co.uk               Eliza            Andrews
#
#              phone_number                                          image_url  \
# 0     (146)994-1635x35992  https://perenual.com/storage/species_image/277...
# 1    001-481-273-3691x127                                                NaN
# 2     (146)994-1635x35992                                                NaN
# 3     (846)669-6651x75948                                                NaN
# 4     (146)994-1635x35992                                                NaN
# ..                    ...                                                ...
# 131  001-481-273-3691x127                                                NaN
# 132   (846)669-6651x75948  https://perenual.com/storage/image/upgrade_acc...
# 133   (846)669-6651x75948  https://perenual.com/storage/species_image/147...
# 134   (146)994-1635x35992  https://perenual.com/storage/image/upgrade_acc...
# 135   (846)669-6651x75948  https://perenual.com/storage/species_image/219...
#
#      longitude   latitude            town      country country_abbreviation  \
# 0    -19.32556  -41.25528      Resplendor    Sao_Paulo                   BR
# 1     33.95015 -118.03917  South Whittier  Los_Angeles                   US
# 2      7.65649    4.92235     Efon-Alaaye        Lagos                   NG
# 3    -19.32556  -41.25528      Resplendor    Sao_Paulo                   BR
# 4     13.70167  -89.10944        Ilopango  El_Salvador                   SV
# ..         ...        ...             ...          ...                  ...
# 131   33.95015 -118.03917  South Whittier  Los_Angeles                   US
# 132  -13.78040   34.45870          Salima     Blantyre                   MW
# 133   37.49223   15.07041         Catania         Rome                   IT
# 134   14.14989  121.31520         Calauan       Manila                   PH
# 135   17.94979  -94.91386        Acayucan  Mexico_City                   MX
#
#     continent
# 0     America
# 1     America
# 2      Africa
# 3     America
# 4     America
# ..        ...
# 131   America
# 132    Africa
# 133    Europe
# 134      Asia
# 135   America
#
# [136 rows x 18 columns]

# %%
plants_data['last_watered'] = pd.to_datetime(plants_data['last_watered'])
plants_data['recording_taken'] = pd.to_datetime(plants_data['recording_taken'])

# %%
plants_data_sorted_by_last_watered = plants_data.sort_values(by='last_watered')
plants_data_sorted_by_last_watered
# Out:
#      plant_id                 name                      scientific_name  \
# 62         22     Bird of Paradise  Heliconia schiedeana 'Fire and Ice'
# 109        22     Bird of Paradise  Heliconia schiedeana 'Fire and Ice'
# 18         22     Bird of Paradise  Heliconia schiedeana 'Fire and Ice'
# 51         10         Dragon tree,                                  NaN
# 97         10         Dragon tree,                                  NaN
# ..        ...                  ...                                  ...
# 110        23  Cordyline Fruticosa                  Cordyline fruticosa
# 63         23  Cordyline Fruticosa                  Cordyline fruticosa
# 114        27        Spathiphyllum                Spathiphyllum (group)
# 22         27        Spathiphyllum                Spathiphyllum (group)
# 67         27        Spathiphyllum                Spathiphyllum (group)
#
#            last_watered     recording_taken  soil_moisture  temperature  \
# 62  2023-12-20 13:03:26 2023-12-20 16:20:57      88.449175    23.157241
# 109 2023-12-20 13:03:26 2023-12-20 16:27:55      88.041032     9.556092
# 18  2023-12-20 13:03:26 2023-12-20 16:32:43      87.760675     9.563896
# 51  2023-12-20 13:04:57 2023-12-20 16:21:07      88.649647    13.948429
# 97  2023-12-20 13:04:57 2023-12-20 16:28:02      88.249686    13.955637
# ..                  ...                 ...            ...          ...
# 110 2023-12-20 14:56:47 2023-12-20 16:28:02      94.745088    11.427459
# 63  2023-12-20 14:56:47 2023-12-20 16:21:03      95.147128    11.412217
# 114 2023-12-20 14:58:20 2023-12-20 16:27:02      94.926514    10.763752
# 22  2023-12-20 14:58:20 2023-12-20 16:31:38      94.662682    10.770323
# 67  2023-12-20 14:58:20 2023-12-20 16:20:25      95.304572    10.755236
#
#                           email botanist_first_name botanist_last_name  \
# 62   gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 109  gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 18   gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 51   gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 97   gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# ..                          ...                 ...                ...
# 110    eliza.andrews@lnhm.co.uk               Eliza            Andrews
# 63     eliza.andrews@lnhm.co.uk               Eliza            Andrews
# 114    carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
# 22     carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
# 67     carl.linnaeus@lnhm.co.uk                Carl           Linnaeus
#
#              phone_number                                          image_url  \
# 62   001-481-273-3691x127  https://perenual.com/storage/image/upgrade_acc...
# 109  001-481-273-3691x127  https://perenual.com/storage/image/upgrade_acc...
# 18   001-481-273-3691x127  https://perenual.com/storage/image/upgrade_acc...
# 51   001-481-273-3691x127                                                NaN
# 97   001-481-273-3691x127                                                NaN
# ..                    ...                                                ...
# 110   (846)669-6651x75948  https://perenual.com/storage/species_image/204...
# 63    (846)669-6651x75948  https://perenual.com/storage/species_image/204...
# 114   (146)994-1635x35992  https://perenual.com/storage/image/upgrade_acc...
# 22    (146)994-1635x35992  https://perenual.com/storage/image/upgrade_acc...
# 67    (146)994-1635x35992  https://perenual.com/storage/image/upgrade_acc...
#
#      longitude  latitude                 town country country_abbreviation  \
# 62    48.35693  10.98461            Friedberg  Berlin                   DE
# 109   48.35693  10.98461            Friedberg  Berlin                   DE
# 18    48.35693  10.98461            Friedberg  Berlin                   DE
# 51    43.50891  16.43915                Split  Zagreb                   HR
# 97    43.50891  16.43915                Split  Zagreb                   HR
# ..         ...       ...                  ...     ...                  ...
# 110   52.53048  13.29371  Charlottenburg-Nord  Berlin                   DE
# 63    52.53048  13.29371  Charlottenburg-Nord  Berlin                   DE
# 114   51.67822  33.91620              Hlukhiv    Kiev                   UA
# 22    51.67822  33.91620              Hlukhiv    Kiev                   UA
# 67    51.67822  33.91620              Hlukhiv    Kiev                   UA
#
#     continent
# 62     Europe
# 109    Europe
# 18     Europe
# 51     Europe
# 97     Europe
# ..        ...
# 110    Europe
# 63     Europe
# 114    Europe
# 22     Europe
# 67     Europe
#
# [136 rows x 18 columns]

# %%
plants_sorted_by_recording_taken = plants_data.sort_values(by='recording_taken')
plants_sorted_by_recording_taken
# Out:
#     plant_id                   name        scientific_name  \
# 54        13        Canna ‘Striata’                    NaN
#
#     longitude   latitude         town        country country_abbreviation  \
# 54   49.68369    8.61839     Bensheim         Berlin                   DE
# 78   36.24624  139.07204      Fujioka          Tokyo                   JP
# 66   36.06386    4.62744     El Achir        Algiers                   DZ
# 42  -19.32556  -41.25528   Resplendor      Sao_Paulo                   BR
# 55   29.65163  -82.32483  Gainesville       New_York                   US
# ..        ...        ...          ...            ...                  ...
# 32   30.21121   74.48180       Malaut        Kolkata                   IN
# 9    20.88953 -156.47432      Kahului       Honolulu                   US
# 20   43.82634  144.09638    Motomachi          Tokyo                   JP
# 33   -6.80000   39.25000     Magomeni  Dar_es_Salaam                   TZ
# 10   32.50070  -94.74049     Longview        Chicago                   US
#
#    continent
# 54    Europe
# 78      Asia
# 66    Africa
# 42   America
# 55   America
# ..       ...
# 32      Asia
# 9    Pacific
# 20      Asia
# 33    Africa
# 10   America
#
# [136 rows x 18 columns]

# %%
alt.Chart(plants_data).mark_circle().encode(
    x='recording_taken:T',
    y='soil_moisture:Q',
    color = 'name:N'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(plants_data).mark_circle().encode(
    x='recording_taken:T',
    y='last_watered:T',
    color = 'name:N'
)
# Out:
# alt.Chart(...)

# %%
plant_19 = plants_data[plants_data['plant_id'] == 19]
# Out:
#      plant_id         name scientific_name        last_watered  \
# 15         19  Musa Basjoo     Musa basjoo 2023-12-20 13:24:30
# 59         19  Musa Basjoo     Musa basjoo 2023-12-20 13:24:30
# 106        19  Musa Basjoo     Musa basjoo 2023-12-20 13:24:30
#
#         recording_taken  soil_moisture  temperature  \
# 15  2023-12-20 16:32:18      89.498517    13.871422
# 59  2023-12-20 16:20:39      90.149488    13.859123
# 106 2023-12-20 16:27:30      89.766334    12.406811
#
#                           email botanist_first_name botanist_last_name  \
# 15   gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 59   gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
# 106  gertrude.jekyll@lnhm.co.uk            Gertrude             Jekyll
#
#              phone_number                                          image_url  \
# 15   001-481-273-3691x127  https://perenual.com/storage/image/upgrade_acc...
# 59   001-481-273-3691x127  https://perenual.com/storage/image/upgrade_acc...
# 106  001-481-273-3691x127  https://perenual.com/storage/image/upgrade_acc...
#
#      longitude  latitude    town   country country_abbreviation continent
# 15   -21.44236  27.46153  Tonota  Gaborone                   BW    Africa
# 59   -21.44236  27.46153  Tonota  Gaborone                   BW    Africa
# 106  -21.44236  27.46153  Tonota  Gaborone                   BW    Africa

# %%
alt.Chart(plant_19).mark_circle(size=100).encode(
    x='recording_taken:T',
    y='temperature:Q',
    color = 'name:N'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(plants_data).mark_circle().encode(
    x='last_watered:T',
    y='temperature:Q',
    color = 'name:N'
)
# Out:
# alt.Chart(...)
